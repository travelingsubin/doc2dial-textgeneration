# %%
cd
# Out:
# /root

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/doc2dial/sharedtask-dialdoc2021.git
# Out:
# fatal: destination path 'sharedtask-dialdoc2021' already exists and is not an empty directory.

# %%
cd sharedtask-dialdoc2021
# Out:
# /content/drive/MyDrive/sharedtask-dialdoc2021

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached tensorflow_tensorboard-1.5.1-py3-none-any.whl (3.0 MB)
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 5.4 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
cd scripts
# Out:
# /content/drive/My Drive/sharedtask-dialdoc2021/scripts

# %%
cd subtask2
# Out:
# /content/drive/My Drive/sharedtask-dialdoc2021/scripts/subtask2

# %%
pip uninstall tensorflow-tensorboard
# Out:
# Found existing installation: tensorflow-tensorboard 1.5.1
# Uninstalling tensorflow-tensorboard-1.5.1:
#   Would remove:
#     /usr/local/bin/tensorboard
#     /usr/local/lib/python3.7/dist-packages/tensorboard/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow_tensorboard-1.5.1.dist-info/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/__init__.py
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/bleach/__init__.py
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/bleach/callbacks.py
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/bleach/encoding.py
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/bleach/linkifier.py
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/bleach/sanitizer.py
#     /usr/local/lib/python3.7/dist-packages/tensorboard/_vendor/bleach/utils.py
# ...

# %%
# !python seq2seq_utils.py --split train --output_dir seq2seq_files
# Out:
# Reusing dataset doc2dial (/root/.cache/huggingface/datasets/doc2dial/document_domain/1.0.1/7ef17069570bdba93bef5e852505bbd8408c6bea4c0341ef84210451d5b34698)
# Reusing dataset doc2dial (/root/.cache/huggingface/datasets/doc2dial/dialogue_domain/1.0.1/7ef17069570bdba93bef5e852505bbd8408c6bea4c0341ef84210451d5b34698)

# %%
# !python seq2seq_utils.py --split validation --output_dir seq2seq_files
# Out:
# Reusing dataset doc2dial (/root/.cache/huggingface/datasets/doc2dial/document_domain/1.0.1/7ef17069570bdba93bef5e852505bbd8408c6bea4c0341ef84210451d5b34698)
# Reusing dataset doc2dial (/root/.cache/huggingface/datasets/doc2dial/dialogue_domain/1.0.1/7ef17069570bdba93bef5e852505bbd8408c6bea4c0341ef84210451d5b34698)

# %%
# !sh run_seq2seq.sh
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:__main__:Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# ...

# %%
import torch
torch.cuda.empty_cache()
